# %% [markdown]
# # Logistic Regression to aid in Feature Selection

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading in data 
train_data = pd.read_csv("data/train.csv")

# Note that y contains binary label indicating if mid_price goes up 
# in next timestep (y = 1) or not (0)



# Handling nan during feature prediction??

# %%
train_data.head(10)
# Out:
#    id  last_price     mid  opened_position_qty   closed_position_qty  \
# 0   0      3842.4  3842.6                   NaN                  NaN
# 1   1      3842.8  3843.4                   6.0                 49.0
# 2   2      3844.0  3844.3                   7.0                 77.0
# 3   3      3843.8  3843.4                   3.0                 34.0
# 4   4      3843.2  3843.1                   3.0                 38.0
# 5   5      3843.6  3844.2                  12.0                 17.0
# 6   6      3843.6  3844.3                   2.0                 37.0
# 7   7      3844.8  3843.5                   4.0                 24.0
# 8   8      3843.4  3843.7                   2.0                 30.0
# 9   9      3844.0  3843.4                   3.0                 12.0
#
#    transacted_qty  d_open_interest    bid1    bid2    bid3 ...  bid2vol  \
# 0           103.0                0  3842.4  3842.0  3841.8 ...        1
# ...

# %%
# Fill NaN entries with average of previous 5 and next 5 column entries

train_data.Series.interpolate(method='spline', limit_direction='both', in_place=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-ce4d30acd4d9> in <module>()
#       1 # Fill NaN entries with average of previous 5 and next 5 column entries
#       2
# ----> 3 train_data.Series.interpolate(method='spline', limit_direction='both', in_place=True)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Series'

# %%
fig = plt.figure()
plt.title('Plotting last_price vs. time')
#plt.plot(N, L1, marker = '.', color='pink', linewidth = 1.5)
#plt.legend(('Eta 1e-6'), loc = 'upper right')
#plt.legend(('Training Error', 'Validation Error'), loc = 'upper right')
plt.xlabel('Time')
plt.ylabel('Last Price')
plt.margins(y=0.02)


#w2, L2 = SGD(X1, Y1, w_start, eta_vals[1], N_epochs)

# 
plt.plot(train_data["id"], train_data["last_price"], marker = '.', linewidth = 1.5)

#w3, L3 = SGD(X1, Y1, w_start, eta_vals[2], N_epochs)
#plt.plot(N, L3, marker = '.', linewidth = 1.5)

#w4, L4 = SGD(X1, Y1, w_start, eta_vals[3], N_epochs)
#plt.plot(N, L4, marker = '.', linewidth = 1.5)


#w5, L5 = SGD(X1, Y1, w_start, eta_vals[4], N_epochs)
#plt.plot(N, L5, marker = '.', linewidth = 1.5)


#plt.legend(('1e-6', '5e-6', '1e-5', '3e-5', '1e-4'), loc = 'center right')

# %%
train_data.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# Random Forest? (ensemble forest)
# SVM 
# Naive Bayes 
#data_corr =
